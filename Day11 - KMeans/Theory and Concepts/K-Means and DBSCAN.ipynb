# %% [markdown]
# ## Problem with K-Means
# - Can fail sometimes on complex datasets

# %%
from sklearn.datasets import make_moons, make_circles
import  matplotlib.pyplot as plt

# %%
X, y = make_moons(n_samples=500, shuffle=True, noise=0.1)

# %%
plt.scatter(X[:,0], X[:,1], c = y)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters=2)
km.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
plt.scatter(X[:,0], X[:,1], c= km.predict(X))
plt.scatter(km.cluster_centers_[:, 0], km.cluster_centers_[:, 1], c= "black",  s = 200, marker="*")
plt.show()

# %%
km.cluster_centers_
# Out:
# array([[ 1.1940413 , -0.05735999],
#        [-0.22822249,  0.57958923]])

# %% [markdown]
# # DBSCAN
# - **Density Based Spatial Clustering of Applications with Noise**
# - Based upon on the idea, that a cluster is a high density area surrounded by low density region
# - Starts by exploring a small area, if density is "good enough" it considered as part of cluster, and explores neigbours and so on, so it groups regions based upon density!

# %%
plt.scatter(X[:,0], X[:,1], c = y)
plt.show()

# %%
from sklearn.cluster import DBSCAN

# %%
dbs = DBSCAN(eps = 0.15 , min_samples=5)

# %%
y_pred = dbs.fit_predict(X)

# %%
plt.scatter(X[:,0], X[:,1], c=y_pred)
plt.show()
