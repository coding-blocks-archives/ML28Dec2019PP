# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = pd.read_csv("Training Data/Linear_X_Train.csv").values
Y = pd.read_csv("Training Data/Linear_Y_Train.csv").values

# %%
X.shape, Y.shape
# Out:
# ((3750, 1), (3750, 1))

# %%
plt.scatter(X, Y)
plt.show()

# %% [markdown]
# ## Normalise Data

# %%
mu = X.mean()
sigma = X.std()

# %%
X = (X - mu)/ sigma

# %% [markdown]
# # Linear Regression

# %%
def hypothesis(x, theta):
    return theta[0] + theta[1]*x

# %%
def error(X, Y, theta):
    m = X.shape[0]
    err = 0
    
    for i in range(m):
        hx = hypothesis(X[i], theta)
        err += ((hx - Y[i])**2)
    
    return err/m

# %%
def gradient(X, Y, theta):
    m = X.shape[0]
    grad = np.zeros((2, ))
    
    for i in range(m):
        hx = hypothesis(X[i], theta)
        grad[0] += (hx-Y[i])*1
        grad[1] += (hx - Y[i])*X[i]
    
    return grad/m

# %%
def gradient_descent(X, Y, lr = 0.1, max_itr = 100):
    m = X.shape[0]
    theta = np.zeros((2,))
    error_list = []
    theta_list = []
    for i in range(max_itr):
        e = error(X, Y, theta)
        error_list.append(e)
        
        
        
        grad = gradient(X, Y, theta)
        
        theta[0] = theta[0] - lr*grad[0]
        theta[1] = theta[1] - lr*grad[1]
        
        theta_list.append((theta[0],theta[1]))
        
        
    return theta, theta_list,  error_list

# %%
theta, theta_list, error_list = gradient_descent(X, Y)

# %%
theta
# Out:
# array([ 0.6838508 , 79.90361453])

# %%
theta_list[:5]
# Out:
# array([[ 0.0683869 ,  7.99057369],
#        [ 0.1299351 , 15.18209002],
#        [ 0.18532849, 21.65445471],
#        [ 0.23518254, 27.47958293],
#        [ 0.28005118, 32.72219834]])

# %%
theta_list = np.array(theta_list)

# %%
np.save("thetas.npy", theta_list)

# %%
plt.plot(error_list)

# %%
y_pred = hypothesis(X, theta)

# %%
plt.scatter(X, Y)
plt.plot(X, y_pred, color="red")

# %% [markdown]
# # Predict for New Data X_test

# %%
X_test = pd.read_csv("Test Cases/Linear_X_Test.csv").values

# %%
X_test = (X_test - mu)/sigma

# %%
predictions_for_testset = hypothesis(X_test, theta)

# %%
predictions_for_testset
# Out:
# array([[-145.66352879],
#        [ -63.75614637],
#        [-198.61470966],
#        ...,
#        [  17.18735982],
#        [ -15.77696247],
#        [ -48.44434904]])

# %%
df = pd.DataFrame(data= predictions_for_testset, columns=['y'])

# %%
df.to_csv("pred.csv", index=False)

# %% [markdown]
# ## Evaluation

# %%
def evaluate(Y_actual, Y_pred):
    num = np.sum((Y_actual - Y_pred)**2)
    denom = np.sum((Y_actual - Y_actual.mean())**2)
    
    return (1 - (num/denom))*100

# %%
evaluate(Y, y_pred)
# Out:
# 97.09612220841039

# %% [markdown]
# # Scikit - learn for Linear regression

# %%
! pip install scikit-learn

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.intercept_
# Out:
# array([3.72798828])

# %%
model.coef_
# Out:
# array([[80.54363185]])

# %%
model.predict(X_test)
# Out:
# array([[-145.66754883],
#        [ -63.75735409],
#        [-198.62054778],
#        ...,
#        [  17.18893131],
#        [ -15.77652282],
#        [ -48.44503103]])

# %%
model.score(X, Y)
# Out:
# 0.9709612233822353

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape, X_test.shape
# Out:
# ((3000, 1), (750, 1))
